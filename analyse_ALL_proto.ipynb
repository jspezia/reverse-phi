# %%
import glob
from psychopy import misc
import numpy as np
import pandas as pd
np.set_printoptions(precision=3, suppress=True)
import pylab
import matplotlib.pyplot as plt
# %matplotlib inline
init = 0
for fn in glob.glob('ALL/*jean01.csv'):
    df = pd.read_csv(fn)
    if (init == 1):
        all_data = [df, all_data]
        all_data = pd.concat(all_data)
    else:
        init = 1
        all_data = df
Sorted = all_data.sort(['shift'])
#print Sorted

# %%
index = []
for i in range(1, 10):
    index.append(np.asarray(Sorted.loc[(Sorted['figure'] == i)]))

# %%
test = Sorted.loc[(Sorted['figure']) == 3]

# %%
test
# Out:
#      ans  contrast      shift     delay  figure
# 146    1        -1 -20.000000  0.211052       3
# 36     1        -1 -20.000000  0.131153       3
# 72     1         1 -20.000000  0.191707       3
# 135    1        -1 -19.731544  0.226303       3
# 88     1         1 -19.194631  0.229565       3
# 57     1        -1 -19.194631  0.719156       3
# 4     -1         1 -19.194631  0.642751       3
# 83    -1         1 -18.926174  0.384178       3
# 44    -1        -1 -18.120805  0.491566       3
# 15     1        -1 -18.120805  0.271423       3
# 94     1         1 -18.120805  0.340514       3
# 105   -1        -1 -17.852349  0.515897       3
# 97    -1         1 -17.315436  0.233389       3
# 11     1        -1 -17.315436  0.220330       3
# 132   -1        -1 -17.315436  0.278230       3
# 63    -1        -1 -17.046980  0.285172       3
# 60    -1        -1 -17.046980  0.406350       3
# 84    -1        -1 -17.046980  0.406788       3
# 1     -1         1 -16.778523  0.273076       3
# 9      1         1 -16.241611  0.692208       3
# 105    1        -1 -16.241611  0.334801       3
# 60    -1         1 -16.241611  0.245657       3
# 120   -1        -1 -15.973154  0.210109       3
# 6      1        -1 -15.704698  0.715094       3
# 61    -1         1 -15.167785  0.246327       3
# 0     -1        -1 -15.167785  0.830726       3
# 32     1        -1 -15.167785  0.394448       3
# 67     1        -1 -14.899329  0.166447       3
# 84     1        -1 -14.093960  0.166341       3
# 145   -1         1 -14.093960  0.262429       3
# ..   ...       ...        ...       ...     ...
# 68     1         1  14.093960  0.256214       3
# 49     1         1  14.093960  0.144938       3
# 15     1         1  14.899329  0.522891       3
# 64     1        -1  15.167785  0.338382       3
# 137   -1        -1  15.167785  1.349572       3
# 53     1         1  15.167785  0.177694       3
# 121    1         1  15.704698  0.346023       3
# 123    1        -1  15.973154  0.321547       3
# 98     1        -1  16.241611  0.191111       3
# 22     1        -1  16.241611  0.222643       3
# 0      1        -1  16.241611  0.476627       3
# 75     1        -1  16.778523  0.294732       3
# 139    1        -1  17.046980  0.249967       3
# 29     1        -1  17.046980  0.432642       3
# 81    -1        -1  17.046980  0.129783       3
# 19     1        -1  17.315436  0.113839       3
# 25     1         1  17.315436  0.270552       3
# 21     1         1  17.315436  0.212531       3
# 137   -1        -1  17.852349  0.417795       3
# 128    1        -1  18.120805  0.391703       3
# 70     1        -1  18.120805  0.235622       3
# 72     1        -1  18.120805  0.337274       3
# 16     1         1  18.926174  0.203103       3
# 3      1        -1  19.194631  0.389336       3
# 100    1         1  19.194631  0.162495       3
# 68    -1        -1  19.194631  0.271651       3
# 38     1         1  19.731544  0.294145       3
# 13     1         1  20.000000  0.272850       3
# 133    1         1  20.000000  0.166256       3
# 78     1        -1  20.000000  0.207145       3
#
# [200 rows x 5 columns]

# %%
results = np.asarray(Sorted)
print results.shape
# Out:
# (600, 5)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(results[:, 2], results[:, 0])
#_ = ax.axis([0., 1., -1.1, 1.1])
_ = ax.set_xlabel('shift')
_ = ax.set_ylabel('perceived direction')

# %%
plt.hist(results[:,2])
# Out:
# (array([ 60.,  60.,  60.,  60.,  60.,  60.,  60.,  60.,  60.,  60.]),
#  array([-20., -16., -12.,  -8.,  -4.,   0.,   4.,   8.,  12.,  16.,  20.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(index[0][:, 2])
# Out:
# (array([ 6.,  5.,  4.,  5.,  5.,  5.,  5.,  4.,  5.,  6.]),
#  array([-20., -16., -12.,  -8.,  -4.,   0.,   4.,   8.,  12.,  16.,  20.]),
#  <a list of 10 Patch objects>)

# %%
N_bin = 10
shift_bin = np.linspace(-20, 20, N_bin+1)
psy = np.ones((N_bin, 2, 9)) * .5

# %%
for i_bin in range(N_bin):
    for i_phi, phi in enumerate([1, -1]):
        ind_phi = results[:, 1] == phi
        for i_fig in range(1,10):
            ind_fig = results[ind_phi, 4] == i_fig
            ind_shift = shift_bin[i_bin] < results[ind_phi, 2][ind_fig]
            ind_shift *= results[ind_phi, 2][ind_fig] <= shift_bin[i_bin+1]
            psy[i_bin, i_phi, i_fig-1] = results[ind_phi, 0][ind_fig][ind_shift].mean()
            
shift_middles = (shift_bin[:-1] + shift_bin[1:])/2.
alpha = .8
fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

for i_fig, color in zip(range(1,4), ['r', 'g', 'b']):
    ax1.plot(shift_middles, psy[:, 0, i_fig-1] * (.8 + .1*i_fig), c=color, alpha=alpha)
ax1.vlines([0], ymin=-1, ymax=1)
for i_fig, color, label in zip(range(1,4), ['r', 'g', 'b'], ['binary', 'MC', 'natural']):
    ax2.plot(shift_middles, psy[:, 1, i_fig-1] * (.8 + .1*i_fig), c=color, alpha=alpha, label=label)
ax2.vlines([0], ymin=-1, ymax=1)
for ax in [ax1, ax2]:
    ax.axis([-20, 20, -1.15, 1.15])
    _ = ax.set_xlabel('shift')
    _ = ax.set_ylabel('perceived direction')
_ = ax2.set_ylabel('perceived direction')
_ = ax2.legend(loc='right')
# Out:
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
